# %% [markdown]
# 人类 -- 今天吃什么 今天穿什么 -- 由information和infer来决定
#
# 人类 -- 预测 -- 识别照片猫（视觉信息或nl）-->抽象成概念->猫汉字
#
# 人类--对数字的抽象->也是一种预测
#
# 人工智能--也是通过information和infer来决定
#
# 以往的算法
# 1.穷举法
# 2.贪心法
# 3.分治法
# 4.动态规划
#
# 机器学习算法不是人设计的
# 算法是由先有数据集
# 从数据集中将自己想要的算法找出来
# 提出一个模型 --> 用数据来训练验证 -->看是得到自己想要的数据
#
# 深度学习是机器学习的一个很小的分支 但在最近10年间变得非常热门
#
# 机器学习的发展

# %% [markdown]
# ![675422f245b9dc5ad20caa6291fe381.png](attachment:675422f245b9dc5ad20caa6291fe381.png)

# %% [markdown]
# 1.早期----依赖一种规则-->需要人制定一个规则-->很复杂的情况不好做--最后代码却来却多无法维护
# 2.经典----手工提取特征---可以是无结构---标注---将其变成一个向量----将输出进行一个映射得到结果
# 3.表示学习---主要用于降维---维度越低---花钱越少

# %% [markdown]
# 维度诅咒--维度越大----矩阵越复杂--对数据的需求就越大--打标签的数据很贵
# 10维空间--压缩成3维 则需要做一个映射 --即找到一个映射矩阵例如3 x N

# %% [markdown]
# ![0d6bc62ad3c14cb2be6d47903d27cab.png](attachment:0d6bc62ad3c14cb2be6d47903d27cab.png)

# %% [markdown]
# # 传统的机器学习策略

# %% [markdown]
# ![be4daa7de546a93a90e5a06b9177d93.png](attachment:be4daa7de546a93a90e5a06b9177d93.png)

# %% [markdown]
# 传统机器学习的挑战
# 无结构数据例如：图像，声音

# %% [markdown]
# ![3a3062ccc606d6dd35539adc4bb126b.png](attachment:3a3062ccc606d6dd35539adc4bb126b.png)

# %% [markdown]
# # 神经网络的介绍
# 以前来源于神经科学
# 现在来源于数学与工程学

# %% [markdown]
# 最重要的算法是反向传播--例如  求偏导数
# 反向传播核心叫做--计算图--输入量（权重）--链式法则

# %% [markdown]
# ![040ebd9cd01b1e20c17dfae755beac4.png](attachment:040ebd9cd01b1e20c17dfae755beac4.png)

# %% [markdown]
# # 神经网络模型发展

# %% [markdown]
# ![11d86a6a17a820016db75bbd59a96a3.png](attachment:11d86a6a17a820016db75bbd59a96a3.png)
